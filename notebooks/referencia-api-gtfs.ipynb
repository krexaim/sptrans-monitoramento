# %%
pip install delta-spark==3.3.2 dotenv
# Out:
# Collecting delta-spark==3.3.2
#   Downloading delta_spark-3.3.2-py3-none-any.whl.metadata (2.2 kB)
# Collecting dotenv
#   Downloading dotenv-0.9.9-py2.py3-none-any.whl.metadata (279 bytes)
# Collecting pyspark<3.6.0,>=3.5.3 (from delta-spark==3.3.2)
#   Downloading pyspark-3.5.7.tar.gz (317.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.4/317.4 MB 7.1 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: importlib_metadata>=1.0.0 in /opt/conda/lib/python3.11/site-packages (from delta-spark==3.3.2) (6.8.0)
# Collecting python-dotenv (from dotenv)
#   Downloading python_dotenv-1.2.1-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.11/site-packages (from importlib_metadata>=1.0.0->delta-spark==3.3.2) (3.17.0)
# Collecting py4j==0.10.9.7 (from pyspark<3.6.0,>=3.5.3->delta-spark==3.3.2)
#   Downloading py4j-0.10.9.7-py2.py3-none-any.whl.metadata (1.5 kB)
# Downloading delta_spark-3.3.2-py3-none-any.whl (22 kB)
# Downloading dotenv-0.9.9-py2.py3-none-any.whl (1.9 kB)
# Downloading py4j-0.10.9.7-py2.py3-none-any.whl (200 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.5/200.5 kB 9.9 MB/s eta 0:00:00
# Downloading python_dotenv-1.2.1-py3-none-any.whl (21 kB)
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (setup.py) ... done
#   Created wheel for pyspark: filename=pyspark-3.5.7-py2.py3-none-any.whl size=317907714 sha256=d28b6e2f8678bd8019985228993d3667ef28f1521f2706a8dd9ed0a8876d2dfb
#   Stored in directory: /home/jovyan/.cache/pip/wheels/58/93/ef/df0fa5d76db2fedf77481d96ab4ae9b9a77eb52fbf2a65b727
# Successfully built pyspark
# Installing collected packages: py4j, python-dotenv, pyspark, dotenv, delta-spark
#   Attempting uninstall: pyspark
#     Found existing installation: pyspark 3.5.0
#     Can't uninstall 'pyspark'. No files were found to uninstall.
# Successfully installed delta-spark-3.3.2 dotenv-0.9.9 py4j-0.10.9.7 pyspark-3.5.7 python-dotenv-1.2.1
# Note: you may need to restart the kernel to use updated packages.

# %%
from pyspark.sql import SparkSession
from pyspark.sql import functions as F
from pyspark.sql.types import *
from delta import configure_spark_with_delta_pip
from delta.tables import DeltaTable
from datetime import datetime

# %%
from dotenv import load_dotenv
import os
load_dotenv('/opt/workspace/.env')
MINIO_ENDPOINT = os.getenv("MINIO_ENDPOINT_DOCKER")
MINIO_ACCESS = os.getenv("MINIO_ROOT_USER")
MINIO_SECRET = os.getenv("MINIO_ROOT_PASSWORD")

# %%
builder = (
    SparkSession.builder.appName("SilverToGold_Delta")
    .config("spark.hadoop.fs.s3a.endpoint", MINIO_ENDPOINT)
    .config("spark.hadoop.fs.s3a.access.key", MINIO_ACCESS)
    .config("spark.hadoop.fs.s3a.secret.key", MINIO_SECRET)
    .config("spark.hadoop.fs.s3a.path.style.access", "true")
    .config("spark.hadoop.fs.s3a.connection.ssl.enabled", "false")
    # Delta Lake
    .config("spark.sql.extensions", "io.delta.sql.DeltaSparkSessionExtension")
    .config("spark.sql.catalog.spark_catalog", "org.apache.spark.sql.delta.catalog.DeltaCatalog")
)
spark = configure_spark_with_delta_pip(builder).getOrCreate()

# %%
from datetime import datetime

today = "data_ref=" + datetime.today().strftime('%Y-%m-%d')
SILVER_PATH = "s3a://silver/"
routes = "gtfs/routes/"
trips = "gtfs/trips/"
stops = "gtfs/stops/"
stop_times = "gtfs/stop_times/"
shapes = "gtfs/shapes/"
posicao = f"posicao/{today}"
linhas = f"linhas/{today}"
paradas = f"paradas/{today}"

gtfs = [routes, trips, stops, stop_times, shapes]
api = [posicao, linhas, paradas]

for data in gtfs + api:
    print(f"\n📂 Lendo: {SILVER_PATH}{data}")
    df = spark.read.format("delta").load(f"{SILVER_PATH}{data}")
    df.printSchema()
    df.show(10, False)
# Out:
# 📂 Lendo: s3a://silver/gtfs/routes/
# root
#  |-- letreiro: string (nullable = true)
#  |-- route_color: string (nullable = true)
#  |-- route_text_color: string (nullable = true)
#  |-- nome_publico: string (nullable = true)
#  |-- terminal_inicial: string (nullable = true)
#  |-- terminal_final: string (nullable = true)
#
# +--------+-----------+----------------+-----------------------------------------+------------------+--------------------+
# |letreiro|route_color|route_text_color|nome_publico                             |terminal_inicial  |terminal_final      |
# +--------+-----------+----------------+-----------------------------------------+------------------+--------------------+
# |1012-10 |509E2F     |FFFFFF          |term. jd. britania - jd. monte belo      |term. jd. britania|jd. monte belo      |
# |1012-21 |509E2F     |FFFFFF          |term. jd. britania - jd. rosinha         |term. jd. britania|jd. rosinha         |
# |1014-10 |509E2F     |FFFFFF          |cptm perus - morro doce                  |cptm perus        |morro doce          |
# |1015-10 |509E2F     |FFFFFF          |term. jd. britania - chac. maria trindade|term. jd. britania|chac. maria trindade|
# |1016-10 |002F6C     |FFFFFF          |cem. do horto - shop. center norte       |cem. do horto     |shop. center norte  |
# |1017-10 |509E2F     |FFFFFF          |perus - conexao vl. iorio                |perus             |conexao vl. iorio   |
# |1018-10 |002F6C     |FFFFFF          |vl. rosa - metro santana                 |vl. rosa          |metro santana       |
# |1019-10 |509E2F     |FFFFFF          |sol nascente - term. pirituba            |sol nascente      |term. pirituba      |
# |1020-10 |509E2F     |FFFFFF          |perus - conexao vl. iorio                |perus             |conexao vl. iorio   |
# |1021-10 |509E2F     |FFFFFF          |cohab brasilandia - term. pirituba       |cohab brasilandia |term. pirituba      |
# +--------+-----------+----------------+-----------------------------------------+------------------+--------------------+
# only showing top 10 rows
#
#
# 📂 Lendo: s3a://silver/gtfs/trips/
# root
#  |-- trip_id: string (nullable = true)
#  |-- letreiro: string (nullable = true)
#  |-- sentido: integer (nullable = true)
#  |-- destino: string (nullable = true)
#  |-- shape_id: integer (nullable = true)
#  |-- dias_funcionamento: string (nullable = true)
#
# +---------+--------+-------+--------------------+--------+------------------+
# |trip_id  |letreiro|sentido|destino             |shape_id|dias_funcionamento|
# +---------+--------+-------+--------------------+--------+------------------+
# |1012-10-0|1012-10 |0      |jd. monte belo      |84609   |USD               |
# |1012-21-0|1012-21 |0      |jd. rosinha         |81195   |U__               |
# |1014-10-0|1014-10 |0      |morro doce          |84061   |U__               |
# |1015-10-0|1015-10 |0      |chac. maria trindade|81148   |USD               |
# |1016-10-0|1016-10 |0      |shop. center norte  |84176   |USD               |
# |1016-10-1|1016-10 |1      |cem. do horto       |84540   |USD               |
# |1017-10-0|1017-10 |0      |conexao vl. iorio   |72355   |USD               |
# |1017-10-1|1017-10 |1      |perus               |72356   |USD               |
# |1018-10-0|1018-10 |0      |metro santana       |71029   |USD               |
# |1018-10-1|1018-10 |1      |vl. rosa            |71030   |USD               |
# +---------+--------+-------+--------------------+--------+------------------+
# only showing top 10 rows
#
#
# 📂 Lendo: s3a://silver/gtfs/stops/
# root
#  |-- id_parada: string (nullable = true)
#  |-- nome_parada: string (nullable = true)
#  |-- latitude: double (nullable = true)
#  |-- longitude: double (nullable = true)
#
# +---------+---------------+----------+----------+
# |id_parada|nome_parada    |latitude  |longitude |
# +---------+---------------+----------+----------+
# |18848    |clinicas       |-23.554022|-46.671108|
# |18849    |vila madalena  |-23.546498|-46.691141|
# |18850    |consolacao     |-23.558094|-46.660205|
# |18851    |conceicao      |-23.635039|-46.641239|
# |18852    |jabaquara      |-23.646033|-46.641028|
# |18853    |sao judas      |-23.625882|-46.640936|
# |18854    |saude          |-23.618245|-46.639139|
# |18855    |praca da arvore|-23.610583|-46.637918|
# |18856    |santa cruz     |-23.598541|-46.636638|
# |18857    |vila mariana   |-23.589359|-46.634677|
# +---------+---------------+----------+----------+
# only showing top 10 rows
#
#
# 📂 Lendo: s3a://silver/gtfs/stop_times/
# root
#  |-- trip_id: string (nullable = true)
#  |-- hora_chegada: string (nullable = true)
#  |-- hora_partida: string (nullable = true)
#  |-- stop_id: integer (nullable = true)
#  |-- sequencia_parada: integer (nullable = true)
#
# +---------+------------+------------+--------+----------------+
# |trip_id  |hora_chegada|hora_partida|stop_id |sequencia_parada|
# +---------+------------+------------+--------+----------------+
# |1012-10-0|07:00:00    |07:00:00    |301790  |1               |
# |1012-10-0|07:01:18    |07:01:18    |301764  |2               |
# |1012-10-0|07:02:36    |07:02:36    |301724  |3               |
# |1012-10-0|07:03:54    |07:03:54    |301730  |4               |
# |1012-10-0|07:05:12    |07:05:12    |30003042|5               |
# |1012-10-0|07:06:30    |07:06:30    |30003045|6               |
# |1012-10-0|07:07:48    |07:07:48    |30003044|7               |
# |1012-10-0|07:09:06    |07:09:06    |30003043|8               |
# |1012-10-0|07:10:24    |07:10:24    |30003013|9               |
# |1012-10-0|07:11:42    |07:11:42    |301693  |10              |
# +---------+------------+------------+--------+----------------+
# only showing top 10 rows
#
#
# 📂 Lendo: s3a://silver/gtfs/shapes/
# root
#  |-- shape_id: string (nullable = true)
#  |-- latitude: double (nullable = true)
#  |-- longitude: double (nullable = true)
#  |-- sequencia_ponto: integer (nullable = true)
#  |-- distancia_acumulada: double (nullable = true)
#
# +--------+----------+----------+---------------+-------------------+
# |shape_id|latitude  |longitude |sequencia_ponto|distancia_acumulada|
# +--------+----------+----------+---------------+-------------------+
# |84609   |-23.432024|-46.787121|1              |0.0                |
# |84609   |-23.431827|-46.787153|2              |22.06              |
# |84609   |-23.431764|-46.787163|3              |29.11              |
# |84609   |-23.431614|-46.787187|4              |45.91              |
# |84609   |-23.43159 |-46.787191|5              |48.6               |
# |84609   |-23.431554|-46.787196|6              |52.62              |
# |84609   |-23.431512|-46.787202|7              |57.31              |
# |84609   |-23.431438|-46.78721 |8              |65.54              |
# |84609   |-23.431388|-46.787215|9              |71.1               |
# |84609   |-23.431378|-46.787218|10             |72.25              |
# +--------+----------+----------+---------------+-------------------+
# only showing top 10 rows
#
#
# 📂 Lendo: s3a://silver/posicao/data_ref=2025-11-12
# root
#  |-- letreiro: string (nullable = true)
#  |-- codigo_linha: integer (nullable = true)
#  |-- sentido: integer (nullable = true)
#  |-- terminal_inicial: string (nullable = true)
#  |-- terminal_final: string (nullable = true)
#  |-- codigo_veiculo: integer (nullable = true)
#  |-- acessibilidade: boolean (nullable = true)
#  |-- ultima_atualizacao: timestamp (nullable = true)
#  |-- latitude: double (nullable = true)
#  |-- longitude: double (nullable = true)
#  |-- hora_referencia: timestamp (nullable = true)
#  |-- data_ref: date (nullable = true)
#  |-- ingest_timestamp: timestamp (nullable = true)
#
# +--------+------------+-------+---------------------------+-----------------+--------------+--------------+-------------------+----------+----------+-------------------+----------+--------------------------+
# |letreiro|codigo_linha|sentido|terminal_inicial           |terminal_final   |codigo_veiculo|acessibilidade|ultima_atualizacao |latitude  |longitude |hora_referencia    |data_ref  |ingest_timestamp          |
# +--------+------------+-------+---------------------------+-----------------+--------------+--------------+-------------------+----------+----------+-------------------+----------+--------------------------+
# |7004-10 |34760       |2      |est. sto. amaro/guido caloi|term. jd. jacira |7316          |false         |2025-11-12 16:13:33|-23.731146|-46.785867|2025-11-12 13:14:00|2025-11-12|2025-11-12 16:14:13.149076|
# |189L-10 |35218       |2      |lapa                       |conexao vl. iorio|10001         |true          |2025-11-12 16:13:21|-23.518296|-46.701809|2025-11-12 13:14:00|2025-11-12|2025-11-12 16:14:13.149076|
# |189L-10 |35218       |2      |lapa                       |conexao vl. iorio|10002         |true          |2025-11-12 16:13:39|-23.486799|-46.710651|2025-11-12 13:14:00|2025-11-12|2025-11-12 16:14:13.149076|
# |189L-10 |2450        |1      |lapa                       |conexao vl. iorio|10003         |true          |2025-11-12 16:13:43|-23.517767|-46.703033|2025-11-12 13:14:00|2025-11-12|2025-11-12 16:14:13.149076|
# |189L-10 |2450        |1      |lapa                       |conexao vl. iorio|10004         |true          |2025-11-12 16:13:49|-23.487432|-46.710806|2025-11-12 13:14:00|2025-11-12|2025-11-12 16:14:13.149076|
# |189L-10 |2450        |1      |lapa                       |conexao vl. iorio|10006         |true          |2025-11-12 16:13:42|-23.48661 |-46.710868|2025-11-12 13:14:00|2025-11-12|2025-11-12 16:14:13.149076|
# |8008-10 |1258        |1      |term. pirituba             |hab. turistica   |10201         |true          |2025-11-12 16:13:43|-23.486916|-46.756807|2025-11-12 13:14:00|2025-11-12|2025-11-12 16:14:13.149076|
# |8008-10 |1258        |1      |term. pirituba             |hab. turistica   |10202         |true          |2025-11-12 16:13:32|-23.47171 |-46.754494|2025-11-12 13:14:00|2025-11-12|2025-11-12 16:14:13.149076|
# |8548-10 |33346       |2      |term. lapa                 |parada de taipas |10203         |true          |2025-11-12 16:13:38|-23.473307|-46.683504|2025-11-12 13:14:00|2025-11-12|2025-11-12 16:14:13.149076|
# |8008-10 |34026       |2      |term. pirituba             |hab. turistica   |10204         |true          |2025-11-12 16:13:29|-23.487694|-46.734561|2025-11-12 13:14:00|2025-11-12|2025-11-12 16:14:13.149076|
# +--------+------------+-------+---------------------------+-----------------+--------------+--------------+-------------------+----------+----------+-------------------+----------+--------------------------+
# only showing top 10 rows
#
#
# 📂 Lendo: s3a://silver/linhas/data_ref=2025-11-12
# root
#  |-- codigo_linha: long (nullable = true)
#  |-- modo_circular: boolean (nullable = true)
#  |-- letreiro: string (nullable = true)
#  |-- sentido_linha: long (nullable = true)
#  |-- terminal_principal: string (nullable = true)
#  |-- terminal_secundario: string (nullable = true)
#  |-- data_ref: date (nullable = true)
#  |-- ingest_timestamp: timestamp (nullable = true)
#
# +------------+-------------+--------+-------------+--------------------+-------------------+----------+--------------------------+
# |codigo_linha|modo_circular|letreiro|sentido_linha|terminal_principal  |terminal_secundario|data_ref  |ingest_timestamp          |
# +------------+-------------+--------+-------------+--------------------+-------------------+----------+--------------------------+
# |35254       |true         |1012-10 |2            |jd. monte belo      |term. jd. britania |2025-11-12|2025-11-12 00:53:05.657731|
# |2486        |true         |1012-10 |1            |jd. monte belo      |term. jd. britania |2025-11-12|2025-11-12 00:53:05.657731|
# |2570        |true         |1012-21 |1            |jd. rosinha         |term. jd. britania |2025-11-12|2025-11-12 00:53:05.657731|
# |35338       |true         |1012-21 |2            |jd. rosinha         |term. jd. britania |2025-11-12|2025-11-12 00:53:05.657731|
# |2609        |true         |1014-10 |1            |morro doce          |cptm perus         |2025-11-12|2025-11-12 00:53:05.657731|
# |35377       |true         |1014-10 |2            |morro doce          |cptm perus         |2025-11-12|2025-11-12 00:53:05.657731|
# |2230        |true         |1015-10 |1            |chac. maria trindade|term. jd. britania |2025-11-12|2025-11-12 00:53:05.657731|
# |34998       |true         |1015-10 |2            |chac. maria trindade|term. jd. britania |2025-11-12|2025-11-12 00:53:05.657731|
# |831         |false        |1016-10 |1            |shop. center norte  |cem. do horto      |2025-11-12|2025-11-12 00:53:05.657731|
# |33599       |false        |1016-10 |2            |shop. center norte  |cem. do horto      |2025-11-12|2025-11-12 00:53:05.657731|
# +------------+-------------+--------+-------------+--------------------+-------------------+----------+--------------------------+
# only showing top 10 rows
#
#
# 📂 Lendo: s3a://silver/paradas/data_ref=2025-11-12
# root
#  |-- codigo_linha: integer (nullable = true)
#  |-- codigo_parada: integer (nullable = true)
#  |-- nome_parada: string (nullable = true)
#  |-- endereco: string (nullable = true)
#  |-- latitude: double (nullable = true)
#  |-- longitude: double (nullable = true)
#  |-- data_ref: date (nullable = true)
#  |-- ingest_timestamp: timestamp (nullable = true)
#
# +------------+-------------+-----------------------------+-----------------------------------------------------------+----------+----------+----------+--------------------------+
# |codigo_linha|codigo_parada|nome_parada                  |endereco                                                   |latitude  |longitude |data_ref  |ingest_timestamp          |
# +------------+-------------+-----------------------------+-----------------------------------------------------------+----------+----------+----------+--------------------------+
# |2497        |640000381    |guerino c/b                  |r coracao de bugre/ av miguel de castro                    |-23.48455 |-46.723093|2025-11-12|2025-11-12 00:53:27.450488|
# |2497        |640000382    |guerino b/c                  |av miguel de castro/ r mal. mendes de morais               |-23.484536|-46.722711|2025-11-12|2025-11-12 00:53:27.450488|
# |2559        |640000360    |pinel b/c                    |r mal. mendes de morais/ ac lateral viaduto                |-23.485948|-46.724827|2025-11-12|2025-11-12 00:53:27.450488|
# |2559        |640000382    |guerino b/c                  |av miguel de castro/ r mal. mendes de morais               |-23.484536|-46.722711|2025-11-12|2025-11-12 00:53:27.450488|
# |35327       |640000361    |agarum c/b                   |av dr. felipe pinel/ terminal pirituba                     |-23.485824|-46.725124|2025-11-12|2025-11-12 00:53:27.450488|
# |35327       |640000381    |guerino c/b                  |r coracao de bugre/ av miguel de castro                    |-23.48455 |-46.723093|2025-11-12|2025-11-12 00:53:27.450488|
# |516         |706334       |parada 14 bis c/b            |                                                           |-23.555608|-46.649766|2025-11-12|2025-11-12 00:53:27.450488|
# |516         |70016562     |parada 2 - getulio vargas c/b|r engenheiro monlevade/ vdto professor bernardino tranchesi|-23.559239|-46.654314|2025-11-12|2025-11-12 00:53:27.450488|
# |516         |440015157    |parada 2 - guianas - c/b     |r honduras/ av brasil                                      |-23.573109|-46.66595 |2025-11-12|2025-11-12 00:53:27.450488|
# |516         |440015159    |parada 2 - estados unidos c/b|r cravinhos/ r haiti                                       |-23.570309|-46.662178|2025-11-12|2025-11-12 00:53:27.450488|
# +------------+-------------+-----------------------------+-----------------------------------------------------------+----------+----------+----------+--------------------------+
# only showing top 10 rows

# %%
# Gold
GOLD_PATH = "s3a://gold/"
dim_linha = "dim_linha/"
dim_parada = "dim_parada/"
fato_posicao = f"fato_posicao/{today}"

gold = [dim_linha, dim_parada, fato_posicao]

for data in gold:
    print(f"\n📂 Lendo: {GOLD_PATH}{data}")
    df = spark.read.format("delta").load(f"{GOLD_PATH}{data}")
    df.printSchema()
    df.show(10, False)
# Out:
# 📂 Lendo: s3a://gold/dim_linha/
# root
#  |-- codigo_linha: long (nullable = true)
#  |-- letreiro: string (nullable = true)
#  |-- modo_circular: boolean (nullable = true)
#  |-- regiao: string (nullable = true)
#  |-- terminal_origem: string (nullable = true)
#  |-- terminal_destino: string (nullable = true)
#  |-- transform_gold_timestamp: timestamp (nullable = true)
#
# +------------+--------+-------------+-----------------+--------------------+------------------+--------------------------+
# |codigo_linha|letreiro|modo_circular|regiao           |terminal_origem     |terminal_destino  |transform_gold_timestamp  |
# +------------+--------+-------------+-----------------+--------------------+------------------+--------------------------+
# |2486        |1012-10 |true         |Área 1 - Noroeste|Jd. Monte Belo      |Term. Jd. Britania|2025-11-12 00:55:27.345849|
# |2570        |1012-21 |true         |Área 1 - Noroeste|Jd. Rosinha         |Term. Jd. Britania|2025-11-12 00:55:27.345849|
# |2609        |1014-10 |true         |Área 1 - Noroeste|Morro Doce          |Cptm Perus        |2025-11-12 00:55:27.345849|
# |2230        |1015-10 |true         |Área 1 - Noroeste|Chac. Maria Trindade|Term. Jd. Britania|2025-11-12 00:55:27.345849|
# |831         |1016-10 |false        |Área 2 - Norte   |Shop. Center Norte  |Cem. Do Horto     |2025-11-12 00:55:27.345849|
# |2141        |1017-10 |false        |Área 1 - Noroeste|Conexao Vl. Iorio   |Perus             |2025-11-12 00:55:27.345849|
# |832         |1018-10 |false        |Área 2 - Norte   |Metro Santana       |Vl. Rosa          |2025-11-12 00:55:27.345849|
# |2495        |1019-10 |false        |Área 1 - Noroeste|Term. Pirituba      |Sol Nascente      |2025-11-12 00:55:27.345849|
# |2497        |1020-10 |false        |Área 1 - Noroeste|Conexao Vl. Iorio   |Perus             |2025-11-12 00:55:27.345849|
# |833         |1021-10 |false        |Área 1 - Noroeste|Term. Pirituba      |Cohab Brasilandia |2025-11-12 00:55:27.345849|
# +------------+--------+-------------+-----------------+--------------------+------------------+--------------------------+
# only showing top 10 rows
#
#
# 📂 Lendo: s3a://gold/dim_parada/
# root
#  |-- codigo_parada: integer (nullable = true)
#  |-- nome_parada: string (nullable = true)
#  |-- latitude: double (nullable = true)
#  |-- longitude: double (nullable = true)
#  |-- num_linhas_atendidas: integer (nullable = true)
#  |-- is_corredor: boolean (nullable = true)
#  |-- linhas_atendidas: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- transform_gold_timestamp: timestamp (nullable = true)
#
# +-------------+-------------------------+----------+----------+--------------------+-----------+------------------------------------------------------+--------------------------+
# |codigo_parada|nome_parada              |latitude  |longitude |num_linhas_atendidas|is_corredor|linhas_atendidas                                      |transform_gold_timestamp  |
# +-------------+-------------------------+----------+----------+--------------------+-----------+------------------------------------------------------+--------------------------+
# |19070        |Via Transversal Sul      |-23.580717|-46.794016|1                   |false      |[809H-10]                                             |2025-11-12 00:55:40.658615|
# |19071        |Av. Dos Ourives, 780     |-23.655442|-46.607946|5                   |false      |[519L-10, 4491-21, N535-11, 5038-10, 4491-10]         |2025-11-12 00:55:40.658615|
# |19072        |Av. Dos Ourives, 780     |-23.655265|-46.607882|5                   |false      |[519L-10, 4491-21, N535-11, 5038-10, 4491-10]         |2025-11-12 00:55:40.658615|
# |19073        |Rod. Arao Sahm, 25020    |-23.373502|-46.575335|1                   |false      |[2024-10]                                             |2025-11-12 00:55:40.658615|
# |19076        |Estr. Mombaca, 1         |-23.734689|-46.796429|1                   |false      |[6015-10]                                             |2025-11-12 00:55:40.658615|
# |19077        |Av. Intercontinental, 625|-23.601516|-46.753583|4                   |false      |[748A-41, N837-11, 6250-10, 775P-10]                  |2025-11-12 00:55:40.658615|
# |104763       |Av. Luca, 455            |-23.569481|-46.559044|1                   |false      |[575C-10]                                             |2025-11-12 00:55:40.658615|
# |105268       |R. Montezina, 226        |-23.574844|-46.569858|6                   |false      |[574J-10, 407Y-10, 3134-10, 5145-10, 3161-10, 573H-10]|2025-11-12 00:55:40.658615|
# |105368       |R. Do Orfanato, 1795     |-23.573757|-46.570172|6                   |false      |[574J-10, 407Y-10, 3134-10, 5145-10, 3161-10, 573H-10]|2025-11-12 00:55:40.658615|
# |105388       |Av. Sapopemba, 1985      |-23.572199|-46.569076|4                   |false      |[4729-10, 5141-10, N503-11, 3141-10]                  |2025-11-12 00:55:40.658615|
# +-------------+-------------------------+----------+----------+--------------------+-----------+------------------------------------------------------+--------------------------+
# only showing top 10 rows
#
#
# 📂 Lendo: s3a://gold/fato_posicaodata_ref=2025-11-12
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# Cell In[6], line 11
#       9 for data in gold:
#      10     print(f"\n📂 Lendo: {GOLD_PATH}{data}")
# ---> 11     df = spark.read.format("delta").load(f"{GOLD_PATH}{data}")
#      12     df.printSchema()
#      13     df.show(10, False)
#
# File /usr/local/spark/python/pyspark/sql/readwriter.py:307, in DataFrameReader.load(self, path, format, schema, **options)
#     305 self.options(**options)
#     306 if isinstance(path, str):
# --> 307     return self._df(self._jreader.load(path))
#     308 elif path is not None:
#     309     if type(path) != list:
#
# File /usr/local/spark/python/lib/py4j-0.10.9.7-src.zip/py4j/java_gateway.py:1322, in JavaMember.__call__(self, *args)
#    1316 command = proto.CALL_COMMAND_NAME +\
#    1317     self.command_header +\
#    1318     args_command +\
#    1319     proto.END_COMMAND_PART
#    1321 answer = self.gateway_client.send_command(command)
# -> 1322 return_value = get_return_value(
#    1323     answer, self.gateway_client, self.target_id, self.name)
#    1325 for temp_arg in temp_args:
#    1326     if hasattr(temp_arg, "_detach"):
#
# File /usr/local/spark/python/pyspark/errors/exceptions/captured.py:185, in capture_sql_exception.<locals>.deco(*a, **kw)
#     181 converted = convert_exception(e.java_exception)
#     182 if not isinstance(converted, UnknownException):
#     183     # Hide where the exception came from that shows a non-Pythonic
#     184     # JVM exception message.
# --> 185     raise converted from None
#     186 else:
#     187     raise
#
# AnalysisException: [PATH_NOT_FOUND] Path does not exist: s3a://gold/fato_posicaodata_ref=2025-11-12.

# %%
spark.stop()
